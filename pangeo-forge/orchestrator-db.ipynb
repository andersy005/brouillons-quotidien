# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
query = (
    "SELECT * from reciperun WHERE feedstock_id=79 AND status='completed' AND conclusion='success'"
)
pd.read_sql(query, 'postgresql://localhost/mylocaldb')
# Out:
#                                            recipe_id  bakery_id  feedstock_id  \
# 0  CMIP6.PMIP.MPI-M.MPI-ESM1-2-LR.past2k.r1i1p1f1...          1            79
# 1  CMIP6.PMIP.MRI.MRI-ESM2-0.past1000.r1i1p1f1.Am...          1            79
# 2  CMIP6.PMIP.MIROC.MIROC-ES2L.past1000.r1i1p1f2....          1            79
#
#                                    head_sha version          started_at  \
# 0  ae7555a321e3f82534e32a77867da39ac08f0658         2022-09-26 16:38:01
# 1  ae7555a321e3f82534e32a77867da39ac08f0658         2022-09-26 16:37:46
# 2  ae7555a321e3f82534e32a77867da39ac08f0658         2022-09-26 16:37:31
#
#   completed_at conclusion     status  \
# 0         None    success  completed
# 1         None    success  completed
# 2         None    success  completed
#
#                                              message    id  is_test  \
# 0  {"deployment_id": 660431386, "environment_url"...  1106    False
# 1  {"deployment_id": 660431385, "environment_url"...  1105    False
# ...
