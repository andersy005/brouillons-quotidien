# %%
import fsspec
from pangeo_forge_recipes.patterns import pattern_from_file_sequence
from pangeo_forge_recipes.recipes import setup_logging
from pangeo_forge_recipes.recipes.reference_hdf_zarr import HDFReferenceRecipe

# %%
setup_logging()

# %%
fs = fsspec.filesystem(
    's3', anon=True, client_kwargs={'endpoint_url': 'https://mghp.osn.xsede.org'}
)

all_paths = sorted(fs.glob('s3://rsignellbucket1/LiveOcean/*.nc'))

# %%
all_paths
# Out:
# ['rsignellbucket1/LiveOcean/ocean_his_0001.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0002.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0003.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0004.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0005.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0006.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0007.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0008.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0009.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0010.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0011.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0012.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0013.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0014.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0015.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0016.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0017.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0018.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0019.nc',
#  'rsignellbucket1/LiveOcean/ocean_his_0020.nc',
# ...

# %%
pattern = pattern_from_file_sequence(['s3://' + path for path in all_paths], 'ocean_time')
pattern
# Out:
# <FilePattern {'ocean_time': 25}>

# %%
recipe = HDFReferenceRecipe(
    pattern,
    netcdf_storage_options={
        'anon': True,
        'client_kwargs': {'endpoint_url': 'https://mghp.osn.xsede.org'},
    },
    identical_dims=['lat_psi', 'lat_rho', 'lat_u', 'lat_v', 'lon_psi', 'lon_rho', 'lon_u', 'lon_v'],
)

# %%
recipe_pruned = recipe.copy_pruned()
recipe_pruned
# Out:
# HDFReferenceRecipe(file_pattern=<FilePattern {'ocean_time': 2}>, storage_config=StorageConfig(target=FSSpecTarget(fs=<fsspec.implementations.local.LocalFileSystem object at 0x7f1e968d5970>, root_path='/tmp/tmppfm_8ynd/QiAYki2O'), cache=CacheFSSpecTarget(fs=<fsspec.implementations.local.LocalFileSystem object at 0x7f1e968d5970>, root_path='/tmp/tmppfm_8ynd/tvsHtXTL'), metadata=MetadataTarget(fs=<fsspec.implementations.local.LocalFileSystem object at 0x7f1e968d5970>, root_path='/tmp/tmppfm_8ynd/isl27oHv')), output_json_fname='reference.json', output_intake_yaml_fname='reference.yaml', netcdf_storage_options={'anon': True, 'client_kwargs': {'endpoint_url': 'https://mghp.osn.xsede.org'}}, target_options={}, inline_threshold=500, output_storage_options={}, concat_dims=[], identical_dims=['lat_psi', 'lat_rho', 'lat_u', 'lat_v', 'lon_psi', 'lon_rho', 'lon_u', 'lon_v'], coo_map={}, coo_dtypes={}, preprocess=None, postprocess=None)

# %%
recipe_pruned.to_function()()
# Out:
# pangeo_forge_recipes.storage - INFO - Opening 's3://rsignellbucket1/LiveOcean/ocean_his_0001.nc' directly.
# pangeo_forge_recipes.storage - INFO - Opening 's3://rsignellbucket1/LiveOcean/ocean_his_0002.nc' directly.

# %%
import xarray as xr

# %%
ref_url = "/tmp/tmppfm_8ynd/QiAYki2O/reference.json"

ref_url = "https://ncsa.osn.xsede.org/Pangeo/pangeo-forge/test/pangeo-forge/staged-recipes/recipe-run-1279/liveocean.zarr/reference.json"

# mapper = fsspec.get_mapper("reference://", fo=ref_url, target_protocol="file",
#                            remote_protocol="s3", remote_options=dict(anon=True),
#                            skip_instance_cache=True)
# mapper

# %%
ref_url = "https://ncsa.osn.xsede.org/Pangeo/pangeo-forge/test/pangeo-forge/staged-recipes/recipe-run-1279/liveocean.zarr/reference.json"

ds = xr.open_dataset(
    "reference://",
    engine='zarr',
    backend_kwargs={
        'consolidated': False,
        'storage_options': {
            'fo': ref_url,
            'remote_options': {'anon': True},
            'remote_protocol': 's3',
        },
    },
    chunks={},
)
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (ocean_time: 2, s_w: 31, eta_rho: 1302, xi_rho: 663,
#                      tracer: 11, s_rho: 30, boundary: 4, eta_u: 1302,
#                      xi_u: 662, eta_v: 1301, xi_v: 663, eta_psi: 1301,
#                      xi_psi: 662)
# Coordinates:
#     lat_psi         (eta_psi, xi_psi) float64 dask.array<chunksize=(651, 331), meta=np.ndarray>
#     lat_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(651, 332), meta=np.ndarray>
#     lat_u           (eta_u, xi_u) float64 dask.array<chunksize=(651, 331), meta=np.ndarray>
#     lat_v           (eta_v, xi_v) float64 dask.array<chunksize=(651, 332), meta=np.ndarray>
#     lon_psi         (eta_psi, xi_psi) float64 dask.array<chunksize=(651, 331), meta=np.ndarray>
#     lon_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(651, 332), meta=np.ndarray>
#     lon_u           (eta_u, xi_u) float64 dask.array<chunksize=(651, 331), meta=np.ndarray>
# ...
